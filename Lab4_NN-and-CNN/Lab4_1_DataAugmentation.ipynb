# %% [markdown]
# # **Lab 4.1 Data Augmentation with PyTorch**

# %%
# %pip install --upgrade pip
# %pip install torch torchvision opencv-python numpy scikit-image matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 2.9 MB/s eta 0:00:01
# Installing collected packages: pip
# Successfully installed pip-25.2
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /Users/bellian/Library/Python/3.9/lib/python/site-packages (2.7.1)
# Requirement already satisfied: torchvision in /Users/bellian/Library/Python/3.9/lib/python/site-packages (0.22.1)
# Requirement already satisfied: opencv-python in /Users/bellian/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: numpy in /Users/bellian/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Requirement already satisfied: scikit-image in /Users/bellian/Library/Python/3.9/lib/python/site-packages (0.24.0)
# Requirement already satisfied: matplotlib in /Users/bellian/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: filelock in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: scipy>=1.9 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: imageio>=2.33 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from scikit-image) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bellian/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from torch.utils.data import Dataset
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Subset
from torch.nn import functional as F
import random
import cv2
import numpy as np
from skimage.util import random_noise
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Complete the `load_data()` function that loads the image using `ImageFolder()` with the specific `transforms.compose()` provided below.
# `load_data()` will return DataLoader() and print the information about the Dataset.
#
# `transforms.Compose()` :
# - `transforms.Resize()`
# - `transforms.ToTensor()`
# - `transforms.Pad()`
# - `transforms.RandomAffine(degrees=45, translate=(0.1, 0.1),scale=(0.8, 1.2), shear=45)`
# - `transforms.CenterCrop()`
#
# Resource : [`transforms.Compose()`](https://pytorch.org/vision/main/generated/torchvision.transforms.Compose.html#compose), [`torchvision.transforms v1`](<https://pytorch.org/vision/stable/transforms.html#v1-api-reference:~:text=custom)%20tv_tensor%20type.-,V1%20API%20Reference,-Geometry>), [`ImageFolder`](https://pytorch.org/vision/main/generated/torchvision.datasets.ImageFolder.html), [`Dataloader`](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#:~:text=Preparing%20your%20data%20for%20training%20with%20DataLoaders)

# %%
def load_data(path):
    ### START CODE HERE ###
    transform = transforms.Compose([
        transforms.Resize((224, 224)), transforms.ToTensor(), transforms.Pad(100, padding_mode="reflect"), transforms.RandomAffine(degrees=45, translate=(0.1, 0.1),scale=(0.8, 1.2), shear=45), transforms.CenterCrop(150)
    ])

    dataset = ImageFolder(path, transform=transform)
    print(f"📃Train Dataset:")
    for idx, class_name in enumerate(dataset.classes):
        class_size = len([img for img, label in dataset.imgs if label == idx])
        print(f"Number of images in class {class_name}: {class_size}")

    print(f"Number of samples: {len(dataset)}")
        

    data_loader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=16, pin_memory=True)
    fig, ax = plt.subplots(4, 4, figsize=(10, 5))
    for i in range(16):
        x = random.randint(0, len(dataset) - 1)
        img, label = data_loader.dataset[x]
        ax[i // 4, i % 4].imshow(img.permute(1, 2, 0))
        ax[i // 4, i % 4].set_title(f"{label}")
        ax[i // 4, i % 4].axis('off')
    plt.tight_layout()
    plt.show()

    return dataset, data_loader

    ### END CODE HERE ###

# %% [markdown]
# Use your load_data() function to load the dataset in the cell below. Then, display the image from the first batch.
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ```
# 📃Train Dataset:
# 	Number of images in class battleship: 44
# 	Number of images in class patrol boat: 35
# 	Number of images in class submarine: 35
# 	Number of samples: 114
# ```
#
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/01.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###
data_loader = load_data("./Ship/Ship/Train")



### END CODE HERE ###
# Out:
# 📃Train Dataset:
# Number of images in class battleship: 44
# Number of images in class patrol boat: 35
# Number of images in class submarine: 35
# Number of samples: 114
# /Users/bellian/Library/Python/3.9/lib/python/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# Now, let's create your own `CustomImageDataset` that performs the augmentation as in the previous section, but also includes the methods `add_gaussian_blur()` and `add_gaussian_noise()`. **<font color="red">DO NOT</font>** use `transforms.Compose()`.
#
# Resource : [CustomImageDataset](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#:~:text=.show()-,Dataset%20class,-torch.utils.data)

# %%
### START CODE HERE ###
class CustomImageDataset(Dataset):
    def __init__(self, path):
        dataset, _ = load_data(path)
        self.dataset = dataset

    
    def __getitem__(self, idx):
        kernel_size = random.choice([3, 5, 7])
        mean = random.uniform(0, 0.1)
        var = random.uniform(0.01, 0.1)
        image, label = self.dataset[idx]
        image = self.add_gaussian_noise(image, mean, var)
        image = self.add_gaussian_blur(image, kernel_size)
        return image,label
    
    def add_gaussian_noise(self, image, mean=0, var=0.01):
        noisy_image = random_noise(image.numpy(), mode='gaussian', mean=mean, var=var)
        return torch.tensor(noisy_image).permute(2, 0, 1)
    
    def add_gaussian_blur(self, image, kernel_size=5):
        blurred_image = transforms.GaussianBlur(kernel_size, sigma=(0.1, 2.0))(image)
        return blurred_image
    
### END CODE HERE ###

# %% [markdown]
# Use your `CustomImageDataset()` function. Then, display the image from the first batch.
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image-2.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/02.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###
dataset = CustomImageDataset("./Ship/Ship/Train")
dataloader = DataLoader(dataset=dataset, batch_size=16, shuffle=True, num_workers=16, pin_memory=True)


### END CODE HERE ###

# %% [markdown]
# Questions
# 1. Discuss effects and benefits of fill_mode or padding_mode.
# 2. What would be amount of augmentation should be so that it would not effect the training performance?
# 3. How can we create Salt-and-Pepper Noise, which is the type that greatly affect the image quality?
# 4. What would be transform parameter to simulate camera lense effect?
